# %% [markdown]
# ##NAME: SHEHZADA GUSHTASP KHAN
# ##E. NO: 01-136232-043
# ##ASSIGNMENT NO: 1
# ##TITLE: GenZ Life Simulator

# %%
import math
responses = {
    "hi" : "Hey bestie!",
    "how are you": "I'm vibing, wbu?",
    "bye": "Aww, see you soon"
}
default_ans = "Hmm... idk what to say"
energy, points, mood = 0, 0, "😒"

# %%
def greet_user():
  name = input("What is your name: ")
  age = int(input("How old are you(years): "))
  user = {"name": name, "age": age}
  # print("")
  # print(user)
  print(" ")
  print("Hello there! Welcome to the chat.")
  print("  ")
  get_response()

# %%
def get_response():
  while True:
    msg = input("What do you say: ")
    if msg.lower() == "bye":
      end_chat()
      return
    elif msg.lower() in responses:
      print(responses[msg.lower()])
    elif msg.lower() == "play" or msg.lower() == "game":
      game = input("Ooo want to play GenZ life Simulator with me?(yes/no): ")
      if game.lower() == "no":
        continue
      elif game.lower() == "yes":
        play_game()

    else:
      print(default_ans)

# %%
def play_game():
  menu = '''\n      1. Study.
      2. Eat.
      3. Play.
      4. Sleep.
      5. Show status
      6. For something unque
      7. quit
      write your choice: '''
  while True:
    choice_game = input(menu)
    update_stats(choice_game)
    if choice_game.lower() == "quit" or choice_game == "7":
      break

# %%
def show_status():
  print(f"energy: {energy}")
  print(f"points: {points}")
  print(f"mood: {mood}")
  return

# %%
def update_stats(choice_game: str):
  global energy, points, mood
  if choice_game.lower() == "study" or choice_game == "1":
      energy -= 20
      points += 10
      mood = "😐"
  elif choice_game.lower() == "eat" or choice_game == "2":
    energy += 15
    mood = "🙂"
  elif choice_game.lower() == "play" or choice_game == "3":
    energy -= 10
    points += 5
    mood = "😎"
  elif choice_game.lower() == "sleep" or choice_game == "4":
    energy = 100
    mood = "😴"
  elif choice_game.lower() == "show status" or choice_game == "5":
    show_status()
  elif choice_game.lower() == "quit" or choice_game == "7":
    end_game()
  elif choice_game == "6":
    print("This is one of my older projects.")
    print("It is TIK TAK TOE GAME, against an unbeatable AI opponent. ")
    print("I hope you enjooy playing it.")
    play_real_game()
    energy += 40
    points += 20
    mood = "😎"
  else:
    print("Invalid choice")

# %%
def end_game():
  show_status()
  print("Thanks for playing!")
  return

# %%
def end_chat():
  print("It was nice talking to you, Good Bye!")
  return

# %%
def main():
  greet_user()

# %%
def print_board(board):
    for row in board:
        print(" | ".join(row))
    print()

# %%
def is_winner(board, player):
    # Check rows, columns, and diagonals
    for row in board:
        if all(cell == player for cell in row):
            return True
    for col in range(3):
        if all(board[row][col] == player for row in range(3)):
            return True
    if all(board[i][i] == player for i in range(3)) or all(board[i][2 - i] == player for i in range(3)):
        return True
    return False

# %%
def is_draw(board):
    return all(cell != ' ' for row in board for cell in row)

# %%
def minimax(board, depth, is_maximizing, alpha=-math.inf, beta=math.inf):
    if is_winner(board, 'X'):
        return -10 + depth
    if is_winner(board, 'O'):
        return 10 - depth
    if is_draw(board):
        return 0

    if is_maximizing:
        best_score = -math.inf
        for i in range(3):
            for j in range(3):
                if board[i][j] == ' ':
                    board[i][j] = 'O'
                    score = minimax(board, depth + 1, False, alpha, beta)
                    board[i][j] = ' '
                    best_score = max(best_score, score)
                    alpha = max(alpha, best_score)
                    if alpha >= beta:
                        break  # Prune
            if alpha >= beta:
                break  # Prune rows
        return best_score
    else:
        best_score = math.inf
        for i in range(3):
            for j in range(3):
                if board[i][j] == ' ':
                    board[i][j] = 'X'
                    score = minimax(board, depth + 1, True, alpha, beta)
                    board[i][j] = ' '
                    best_score = min(best_score, score)
                    beta = min(beta, best_score)
                    if beta <= alpha:
                        break  # Prune
            if beta <= alpha:
                break  # Prune rows
        return best_score

# %%
def best_move(board):
    best_score = -math.inf
    move = None
    alpha = -math.inf
    beta = math.inf

    # Prioritize moves: center, corners, edges
    moves = []
    if board[1][1] == ' ':
        moves.append((1, 1))
    corners = [(0,0), (0,2), (2,0), (2,2)]
    for corner in corners:
        if board[corner[0]][corner[1]] == ' ':
            moves.append(corner)
    edges = [(0,1), (1,0), (1,2), (2,1)]
    for edge in edges:
        if board[edge[0]][edge[1]] == ' ':
            moves.append(edge)
    for i in range(3):
        for j in range(3):
            if (i, j) not in moves and board[i][j] == ' ':
                moves.append((i, j))

    for (i, j) in moves:
        board[i][j] = 'O'
        score = minimax(board, 0, False, alpha, beta)
        board[i][j] = ' '
        if score > best_score:
            best_score = score
            move = (i, j)
        alpha = max(alpha, best_score)
        if alpha >= beta:
            break  # Prune
    return move

# %%
def play_real_game():
    board = [[' ' for _ in range(3)] for _ in range(3)]
    print("Tic-Tac-Toe: AI (O) vs Human (X)")
    print_board(board)

    while True:
        # Player's move (existing input validation)
        while True:
            try:
                row, col = map(int, input("Enter move (1-3 row and column): ").split())
                row -= 1
                col -= 1
                if 0 <= row <= 2 and 0 <= col <= 2 and board[row][col] == ' ':
                    break
                print("Invalid move! Try again.")
            except ValueError:
                print("Enter two integers (e.g., '2 3').")

        board[row][col] = 'X'
        print_board(board)

        if is_winner(board, 'X'):
            print("You win!")
            break
        if is_draw(board):
            print("Draw!")
            break

        # AI's move
        ai_row, ai_col = best_move(board)
        board[ai_row][ai_col] = 'O'
        print("AI's move:")
        print_board(board)

        if is_winner(board, 'O'):
            print("AI wins!")
            break
        if is_draw(board):
            print("Draw!")
            break

# %%
if __name__ == "__main__":
  main()
# Out:
# What is your name: Shehzada Gushtasp Khan
# How old are you(years): 20
#
# Hello there! Welcome to the chat.
#
# What do you say: hi
# Hey bestie!
# What do you say: how are you
# I'm vibing, wbu?
# What do you say: game
# Ooo want to play GenZ life Simulator with me?(yes/no): no
# What do you say: play
# Ooo want to play GenZ life Simulator with me?(yes/no): yes
#
#       1. Study.
#       2. Eat.
#       3. Play.
#       4. Sleep.
#       5. Show status
#       6. For something unque
#       7. quit
#       write your choice: 1
#
#       1. Study.
#       2. Eat.
#       3. Play.
#       4. Sleep.
#       5. Show status
#       6. For something unque
#       7. quit
#       write your choice: 2
#
#       1. Study.
#       2. Eat.
#       3. Play.
#       4. Sleep.
#       5. Show status
#       6. For something unque
#       7. quit
#       write your choice: 3
#
#       1. Study.
#       2. Eat.
#       3. Play.
#       4. Sleep.
#       5. Show status
# ...

# %%
get_response()
# Out:
# What do you say: game
# Ooo want to play GenZ life Simulator with me?(yes/no): yes
#
#       1. Study.
#       2. Eat.
#       3. Play.
#       4. Sleep.
#       5. Show status
#       6. For something unque
#       7. quit
#       write your choice: 5
# energy: 100
# points: 30
# mood: 😴
#
#       1. Study.
#       2. Eat.
#       3. Play.
#       4. Sleep.
#       5. Show status
#       6. For something unque
#       7. quit
#       write your choice: 6
# This is one of my older projects.
# It is TIK TAK TOE GAME, against an unbeatable AI opponent.
# I hope you enjooy playing it.
# Tic-Tac-Toe: AI (O) vs Human (X)
#   |   |
#   |   |
#   |   |
#
# Enter move (1-3 row and column): 1 1
# X |   |
#   |   |
#   |   |
#
# AI's move:
# X |   |
#   | O |
#   |   |
#
# Enter move (1-3 row and column): 2 2
# Invalid move! Try again.
# Enter move (1-3 row and column): 2 3
# X |   |
#   | O | X
#   |   |
#
# AI's move:
# X |   | O
#   | O | X
#   |   |
#
# ...
